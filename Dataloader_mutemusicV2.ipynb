# %%
import os, pickle
import numpy as np
import pandas as pd
import librosa

# %%
#paths
scale = 'MISTROI'
sub = 'sub-03'
dataset = 'mutemusic'
tracks_path = f'/home/maellef/DataBase/{dataset}/stimuli'
data_path = f'/home/maellef/DataBase/{dataset}/Preprocessed_fMRI'
output_path = '/home/maellef/git/MuteMusic_analysis/data/training_data'

#-----------------specific to muetmusic
silenced_tracks = True
stim_tracks = 'silenced' if silenced_tracks else 'full' 
tracks_path = os.path.join(tracks_path, stim_tracks)

sessions_data = './data/sub_session_data.tsv'
sessions_df = pd.read_csv(sessions_data, sep='\t')
silences_data = './data/silences_data.tsv'
silences_df = pd.read_csv(silences_data, sep='\t')

# %%
def find_label_value(name, label):
    label += '-' if label[-1] != '-' else label
    startval = name.find(label)+len(label)
    endval = startval
    for i in range(startval, len(name)):
        if name[i] in ['_', '.']:
            break
        endval+=1
    return name[startval:endval]

# %%
#structure to store all data pair (wav-fMRI)
df = pd.DataFrame({
})
wavbold = []
#general args
tr = 1.49
hrf_nb_tr = 0

sub_path = os.path.join(data_path, scale, sub)

for filename in os.listdir(sub_path):
    #load bold data
    runpath = os.path.join(sub_path, filename)
    with np.load(runpath) as data:
        x = data['X']
    data.close()
    
    #args necessary to extract infos from run
    sub = sub
    ses = int(find_label_value(filename, 'ses'))
    #------------different between friends and mutemusic
    run = int(find_label_value(filename, 'run'))

    #-----------specific to mutemusic
    run_data = sessions_df.loc[(sessions_df['sub']==sub)&
                                (sessions_df['session']==ses)&
                                (sessions_df['run']==run)]
    
    for i, track in run_data.iterrows():
        #track infos
        groupe = track['Groupe']
        category = track['category']
        score = track['value']
        repetition = track['repetition']
        title_silenced = track['title']
        title = title_silenced.replace('_silenced','')
        onset = round(track['onset'])
        duration = round(track['total_duration'])

        #load silenced track
        selected_title = title_silenced if silenced_tracks else title
        wav_path = os.path.join(tracks_path, category, selected_title)
        wav, sr = librosa.load(wav_path, sr=None)

        #bold data for track (WITH HRF delay !!!!!)
        tr_onset = round(onset/tr) + hrf_nb_tr
        tr_duration = round(duration/tr)
        track_fmri = x[tr_onset:tr_onset+tr_duration, :]
        print(title, duration, track_fmri.shape, sr)

        #define timestamps to extract both music and silence    
        sdf = silences_df.loc[silences_df['track']==title]
        sdf = sdf.drop(['category', 'track'], axis='columns').reset_index()
        for col in sdf.columns:
            if 'duration' not in col:
                sdf[col]=sdf[col]/sr
        

        #general----------------------------------------------------------
        #extract corresponding wav/bold
        bold_segment = track_fmri
        wav_segment = wav
        segment_df = pd.Series({
            'session':ses,
            'run':run,
            'category':category,
            'sr':sr,
            'groupe':groupe,
            'title':selected_title,
            'score':score,
            'repetition':repetition
        }).to_frame().T
                
        segment_df = pd.concat([segment_df, sdf], axis='columns')
        print(segment_df)
        df = pd.concat([df, segment_df], axis='rows', ignore_index=True)  
        wavbold.append((wav_segment, bold_segment))

df.to_csv(os.path.join(output_path, f'{dataset}_{sub}_{stim_tracks}_metadata.tsv'), sep='\t')
with open(os.path.join(output_path, f'{dataset}_{sub}_{stim_tracks}_pairWavBold'), 'wb') as f: 
    pickle.dump(wavbold, f)
# Out:
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme.wav 54 (36, 210) 48000
#   session run   category     sr groupe  \
# 0       1   5  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Super_Mario_64_BobOmb_Battlefield_(Extended)_T...     0          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000542          4.0  ...  53.435563          5.0  38.836958  43.836958
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  20.406021  25.406021          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Underwater_Theme.wav 46 (31, 210) 48000
#   session run   category     sr groupe  \
# 0       1   5  Synthetic  48000      F
#
#                                               title score repetition  \
# 0  Super_Mario_Bros_3_Underwater_Theme_silenced.wav     4          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000208          4.0  ...  42.086417          4.0  12.343229  16.343229
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  26.447813  30.447813          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Space_Harrier_Music_MAIN_THEME.wav 48 (32, 210) 48000
#   session run   category     sr groupe  \
# 0       1   5  Synthetic  48000      U
#
#                                          title score repetition     index  \
# 0  Space_Harrier_Music_MAIN_THEME_silenced.wav     0          1  0.000604
#
#    S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  S3_duration  \
# 0          6.0  ...  33.167458          6.0  5.150083  11.150083          NaN
#
#    S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Dreaming_of_Bag_End.wav 52 (35, 210) 48000
#   session run    category     sr groupe                             title  \
# 0       1   5  Orchestral  48000      U  Dreaming_of_Bag_End_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     0          1  0.000917          4.0  ...  42.534917          4.0
#
#    S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  7.577625  11.577625          5.0  26.528479  31.528479          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Creep.wav 49 (33, 210) 48000
#   session run category     sr groupe               title score repetition  \
# 0       1   5   Lyrics  48000      F  Creep_silenced.wav     3          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001646          4.0  ...  11.254437          4.0  28.208938  32.208937
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  42.302771  46.302771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Athletic_Theme.wav 50 (34, 210) 48000
#   session run   category     sr groupe  \
# 0       1   5  Synthetic  48000      F
#
#                                             title score repetition     index  \
# 0  Super_Mario_Bros_3_Athletic_Theme_silenced.wav     4          1  0.000125
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  16.971146          6.0  38.193375  44.193375
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Star_Trek_the_Next_Generation_(Main_Title).wav 56 (38, 210) 48000
#   session run    category     sr groupe  \
# 0       1   5  Orchestral  48000      F
#
#                                                title score repetition  \
# 0  Star_Trek_the_Next_Generation_(Main_Title)_sil...     3          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000729          5.0  ...  12.566896          5.0  40.667979  45.667979
#
#    S3_duration  S3_start   S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  18.95725  22.95725          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Rain.wav 48 (32, 210) 48000
#   session run category     sr groupe              title score repetition  \
# 0       1   5   Lyrics  48000      U  Rain_silenced.wav     0          1
#
#     index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.0015          4.0  ...  47.641125          4.0  30.042458  34.042458
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  19.668792  23.668792          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Synchronicity.wav 47 (32, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       1   5   Lyrics  48000      U  Synchronicity_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001396          4.0  ...  13.070875          4.0  19.838062
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  23.838062          4.0  35.685208  39.685208          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# I_ll_Be_There_for_You.wav 47 (32, 210) 48000
#   session run category     sr groupe                               title  \
# 0       1   5   Lyrics  48000      F  I_ll_Be_There_for_You_silenced.wav
#
#   score repetition    index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          1  0.00175          4.0  ...  39.415062          4.0
#
#     S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  14.130021  18.130021          4.0  24.439187  28.439187          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme.wav 54 (36, 210) 48000
#   session run   category     sr groupe  \
# 0       2   5  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Super_Mario_64_BobOmb_Battlefield_(Extended)_T...     0          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000542          4.0  ...  53.435563          5.0  38.836958  43.836958
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  20.406021  25.406021          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Underwater_Theme.wav 46 (31, 210) 48000
#   session run   category     sr groupe  \
# 0       2   5  Synthetic  48000      F
#
#                                               title score repetition  \
# 0  Super_Mario_Bros_3_Underwater_Theme_silenced.wav     4          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000208          4.0  ...  42.086417          4.0  12.343229  16.343229
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  26.447813  30.447813          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Space_Harrier_Music_MAIN_THEME.wav 48 (32, 210) 48000
#   session run   category     sr groupe  \
# 0       2   5  Synthetic  48000      U
#
#                                          title score repetition     index  \
# 0  Space_Harrier_Music_MAIN_THEME_silenced.wav     0          2  0.000604
#
#    S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  S3_duration  \
# 0          6.0  ...  33.167458          6.0  5.150083  11.150083          NaN
#
#    S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Dreaming_of_Bag_End.wav 52 (35, 210) 48000
#   session run    category     sr groupe                             title  \
# 0       2   5  Orchestral  48000      U  Dreaming_of_Bag_End_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     1          2  0.000917          4.0  ...  42.534917          4.0
#
#    S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  7.577625  11.577625          5.0  26.528479  31.528479          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Creep.wav 49 (33, 210) 48000
#   session run category     sr groupe               title score repetition  \
# 0       2   5   Lyrics  48000      F  Creep_silenced.wav     2          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001646          4.0  ...  11.254437          4.0  28.208938  32.208937
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  42.302771  46.302771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Athletic_Theme.wav 50 (34, 210) 48000
#   session run   category     sr groupe  \
# 0       2   5  Synthetic  48000      F
#
#                                             title score repetition     index  \
# 0  Super_Mario_Bros_3_Athletic_Theme_silenced.wav     4          2  0.000125
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  16.971146          6.0  38.193375  44.193375
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Star_Trek_the_Next_Generation_(Main_Title).wav 56 (38, 210) 48000
#   session run    category     sr groupe  \
# 0       2   5  Orchestral  48000      F
#
#                                                title score repetition  \
# 0  Star_Trek_the_Next_Generation_(Main_Title)_sil...     0          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000729          5.0  ...  12.566896          5.0  40.667979  45.667979
#
#    S3_duration  S3_start   S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  18.95725  22.95725          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Rain.wav 48 (32, 210) 48000
#   session run category     sr groupe              title score repetition  \
# 0       2   5   Lyrics  48000      U  Rain_silenced.wav     0          2
#
#     index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.0015          4.0  ...  47.641125          4.0  30.042458  34.042458
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  19.668792  23.668792          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Synchronicity.wav 47 (32, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       2   5   Lyrics  48000      U  Synchronicity_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001396          4.0  ...  13.070875          4.0  19.838062
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  23.838062          4.0  35.685208  39.685208          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# I_ll_Be_There_for_You.wav 47 (32, 210) 48000
#   session run category     sr groupe                               title  \
# 0       2   5   Lyrics  48000      F  I_ll_Be_There_for_You_silenced.wav
#
#   score repetition    index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          2  0.00175          4.0  ...  39.415062          4.0
#
#     S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  14.130021  18.130021          4.0  24.439187  28.439187          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Sonic_The_Hedgehog_OST_Green_Hill_Zone.wav 52 (35, 210) 48000
#   session run   category     sr groupe  \
# 0       3   1  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Sonic_The_Hedgehog_OST_Green_Hill_Zone_silence...     1          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000521          4.0  ...  25.564604          5.0  32.040979  37.040979
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  44.322771  48.322771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Shinobi_Walk_(level_4_2).wav 52 (35, 210) 48000
#   session run   category     sr groupe  \
# 0       3   1  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Shinobi_3_Return_Of_The_Ninja_Master_OST_Shino...     0          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000417          5.0  ...  31.158896          4.0  44.048125  48.048125
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  16.023958  20.023958          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Living_Together.wav 71 (48, 210) 48000
#   session run category     sr groupe                         title score  \
# 0       3   1   Lyrics  48000      U  Living_Together_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          3  0.001333          4.0  ...  33.575458          4.0  43.692104
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  47.692104          4.0  10.233438  14.233438          6.0  60.423437
#
#      S4_stop
# 0  66.423438
#
# [1 rows x 21 columns]
# Body_and_soul.wav 59 (40, 210) 48000
#   session run    category     sr groupe                       title score  \
# 0       3   1  Orchestral  48000      F  Body_and_soul_silenced.wav     2
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          3  0.001042          5.0  ...  43.926812          6.0  13.229208
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  19.229208          4.0  26.997646  30.997646          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_(NES)_Music_Underground_Theme.wav 49 (33, 210) 48000
#   session run   category     sr groupe  \
# 0       3   1  Synthetic  48000      F
#
#                                                title score repetition  \
# 0  Super_Mario_Bros_(NES)_Music_Underground_Theme...     4          3
#
#       index  S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  \
# 0  0.000146          6.0  ...  32.507583          6.0  7.632917  13.632917
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# The_Imperial_March_(Darth_Vaders_Theme).wav 48 (32, 210) 48000
#   session run    category     sr groupe  \
# 0       3   1  Orchestral  48000      F
#
#                                                title score repetition  \
# 0  The_Imperial_March_(Darth_Vaders_Theme)_silenc...     3          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000625          4.0  ...  21.158583          4.0  40.869875  44.869875
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  28.288167  32.288167          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Main_Title_Terminator_2_Theme_(Remastered_2017).wav 54 (36, 210) 48000
#   session run    category     sr groupe  \
# 0       3   1  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  Main_Title_Terminator_2_Theme_(Remastered_2017...     0          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000687          5.0  ...  39.258875          4.0  13.891438  17.891437
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  46.057938  51.057938          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Never_Gonna_Give_You_Up.wav 50 (34, 210) 48000
#   session run category     sr groupe                                 title  \
# 0       3   1   Lyrics  48000      F  Never_Gonna_Give_You_Up_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          3  0.001375          6.0  ...  29.175937          6.0
#
#     S2_start    S2_stop  S3_duration  S3_start  S3_stop  S4_duration  \
# 0  42.416271  48.416271          NaN       NaN      NaN          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Boss_Battle.wav 57 (38, 210) 48000
#   session run   category     sr groupe  \
# 0       3   1  Synthetic  48000      F
#
#                                          title score repetition     index  \
# 0  Super_Mario_Bros_3_Boss_Battle_silenced.wav     4          3  0.000021
#
#    S1_duration  ...   S1_stop  S2_duration  S2_start   S2_stop  S3_duration  \
# 0          4.0  ...  18.52825          4.0  29.19875  33.19875          6.0
#
#     S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  44.163792  50.163792          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Original_Tetris_theme_(Tetris_Soundtrack).wav 50 (34, 210) 48000
#   session run   category     sr groupe  \
# 0       3   1  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Original_Tetris_theme_(Tetris_Soundtrack)_sile...     2          3
#
#       index  S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  \
# 0  0.000562          6.0  ...  36.444604          6.0  6.001604  12.001604
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Streets_Of_Rage_1_OST_Stage_1.wav 45 (30, 210) 48000
#   session run   category     sr groupe  \
# 0       1   2  Synthetic  48000      U
#
#                                         title score repetition    index  \
# 0  Streets_Of_Rage_1_OST_Stage_1_silenced.wav     0          1  0.00025
#
#    S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  S3_duration  \
# 0          5.0  ...  30.75425          6.0  11.895896  17.895896          NaN
#
#    S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Moonlight_Sonata.wav 47 (32, 210) 48000
#   session run    category     sr groupe                          title score  \
# 0       1   2  Orchestral  48000      F  Moonlight_Sonata_silenced.wav     2
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001021          6.0  ...  40.494229          6.0  13.050833
#
#      S2_stop  S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0  19.050833          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Legend_of_Zelda_The_(NES)_Music_Overworld_Theme.wav 50 (34, 210) 48000
#   session run   category     sr groupe  \
# 0       1   2  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Legend_of_Zelda_The_(NES)_Music_Overworld_Them...     0          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000104          4.0  ...  41.970917          4.0  14.364688  18.364687
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  24.513021  28.513021          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_(NES)_Music_Overworld_Theme.wav 59 (40, 210) 48000
#   session run   category     sr groupe  \
# 0       1   2  Synthetic  48000      F
#
#                                                title score repetition  index  \
# 0  Super_Mario_Bros_(NES)_Music_Overworld_Theme_s...     4          1    0.0
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          5.0  ...  17.709646          4.0  34.984729  38.984729
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          6.0  48.033271  54.033271          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Gangstas_Paradise.wav 61 (41, 210) 48000
#   session run category     sr groupe                           title score  \
# 0       1   2   Lyrics  48000      F  Gangstas_Paradise_silenced.wav     4
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001667          5.0  ...  58.567875          5.0  41.285729
#
#      S2_stop  S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  46.285729          5.0  9.717625  14.717625          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# il_porco_rosso.wav 66 (44, 210) 48000
#   session run    category     sr groupe                        title score  \
# 0       1   2  Orchestral  48000      U  il_porco_rosso_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.000875          4.0  ...  43.998625          4.0  15.888458
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  19.888458          4.0  30.774062  34.774062          4.0  50.554917
#
#      S4_stop
# 0  54.554917
#
# [1 rows x 21 columns]
# Aladdin_Genesis_Music_Ending.wav 65 (44, 210) 48000
#   session run   category     sr groupe  \
# 0       1   2  Synthetic  48000      U
#
#                                        title score repetition     index  \
# 0  Aladdin_Genesis_Music_Ending_silenced.wav     3          1  0.000375
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  12.172729          5.0  21.721125  26.721125
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  46.125708  51.125708          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_(NES)_Music_Castle_Theme.wav 47 (32, 210) 48000
#   session run   category     sr groupe  \
# 0       1   2  Synthetic  48000      F
#
#                                                title score repetition  \
# 0  Super_Mario_Bros_(NES)_Music_Castle_Theme_sile...     4          1
#
#       index  S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000063          6.0  ...  24.55375          6.0  32.374187  38.374187
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# No_Woman_No_Cry.wav 64 (43, 210) 48000
#   session run category     sr groupe                         title score  \
# 0       1   2   Lyrics  48000      F  No_Woman_No_Cry_silenced.wav     4
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001271          5.0  ...  63.422729          5.0  32.528854
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  37.528854          6.0  43.767917  49.767917          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# Make_Em_Laugh.wav 60 (40, 210) 48000
#   session  run    category     sr groupe                       title score  \
# 0       1    2  Orchestral  48000      U  Make_Em_Laugh_silenced.wav     1
# 1     NaN  NaN         NaN    NaN    NaN                         NaN   NaN
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001000          5.0  ...  35.293875          6.0  16.790354
# 1        NaN  0.001625          4.0  ...  13.898771          4.0  52.103646
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  22.790354          4.0  52.674896  56.674896          NaN        NaN
# 1  56.103646          4.0  24.719146  28.719146          4.0  34.446062
#
#      S4_stop
# 0        NaN
# 1  38.446062
#
# [2 rows x 21 columns]
# Lux_Aeterna_from_Requiem_for_a_Dream.wav 60 (40, 210) 48000
#   session run    category     sr groupe  \
# 0       2   3  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  Lux_Aeterna_from_Requiem_for_a_Dream_silenced.wav     2          2
#
#       index  S1_duration  ...  S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000771          6.0  ...   13.926          4.0  29.763063  33.763062
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  40.842771  45.842771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Another_Brick_In_The_Wall_(Part_1)_lyrics.wav 60 (40, 210) 48000
#   session run category     sr groupe  \
# 0       2   3   Lyrics  48000      U
#
#                                                title score repetition  \
# 0  Another_Brick_In_The_Wall_(Part_1)_lyrics_sile...     0          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001708          4.0  ...  13.269979          6.0  44.086583  50.086583
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  20.907062  25.907062          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Seinfeld_Official_Soundtrack_(Seinfeld_Theme).wav 52 (35, 210) 48000
#   session run    category     sr groupe  \
# 0       2   3  Orchestral  48000      F
#
#                                                title score repetition  \
# 0  Seinfeld_Official_Soundtrack_(Seinfeld_Theme)_...     4          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000979          5.0  ...  24.054854          4.0  40.662542  44.662542
#
#    S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  8.522271  12.522271          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Material_Girl.wav 50 (34, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       2   3   Lyrics  48000      F  Material_Girl_silenced.wav     4
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001729          4.0  ...  41.991167          4.0  18.624063
#
#      S2_stop  S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  22.624063          4.0  7.444479  11.444479          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# The_4_Seasons_Op_8_4_RV_297_Winter.wav 60 (40, 210) 48000
#   session run    category     sr groupe  \
# 0       2   3  Orchestral  48000      F
#
#                                              title score repetition    index  \
# 0  The_4_Seasons_Op_8_4_RV_297_Winter_silenced.wav     2          2  0.00075
#
#    S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  S3_duration  \
# 0          5.0  ...  54.770792          6.0  6.897687  12.897687          4.0
#
#     S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  18.971875  22.971875          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Populous_(SNES_SFC)_BGM_01_Title_Theme.wav 49 (33, 210) 48000
#   session run   category     sr groupe  \
# 0       2   3  Synthetic  48000      U
#
#                                                title score repetition   index  \
# 0  Populous_(SNES_SFC)_BGM_01_Title_Theme_silence...     0          2  0.0005
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  37.720542          6.0  18.864021  24.864021
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# The_Pink_Panther_Theme.wav 45 (30, 210) 48000
#   session run    category     sr groupe                                title  \
# 0       2   3  Orchestral  48000      F  The_Pink_Panther_Theme_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          2  0.000937          5.0  ...  28.504229          6.0
#
#     S2_start    S2_stop  S3_duration  S3_start  S3_stop  S4_duration  \
# 0  38.234083  44.234083          NaN       NaN      NaN          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Goodbye_Blue_Sky.wav 48 (32, 210) 48000
#   session run category     sr groupe                          title score  \
# 0       2   3   Lyrics  48000      U  Goodbye_Blue_Sky_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration  S2_start  \
# 0          2  0.001521          6.0  ...  26.245562          6.0  5.299479
#
#      S2_stop  S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0  11.299479          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno.wav 53 (36, 210) 48000
#   session run    category     sr groupe  \
# 0       2   3  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno_silenc...     0          2
#
#       index  S1_duration  ...  S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000833          4.0  ...  25.3685          4.0  43.136458  47.136458
#
#    S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  7.484708  12.484708          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Monday_Monday.wav 53 (36, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       2   3   Lyrics  48000      F  Monday_Monday_silenced.wav     1
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001417          4.0  ...  14.102521          4.0  44.471583
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  48.471583          5.0  22.496021  27.496021          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# Gnossienne_No1.wav 63 (42, 210) 48000
#   session run    category     sr groupe                        title score  \
# 0       3   4  Orchestral  48000      F  Gnossienne_No1_silenced.wav     1
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          3  0.000958          4.0  ...  61.327333          4.0  20.895458
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  24.895458          4.0  42.685042  46.685042          4.0  8.876062
#
#      S4_stop
# 0  12.876062
#
# [1 rows x 21 columns]
# Babooshka.wav 55 (37, 210) 48000
#   session run category     sr groupe                   title score repetition  \
# 0       3   4   Lyrics  48000      U  Babooshka_silenced.wav     0          3
#
#       index  S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  \
# 0  0.001187          4.0  ...  24.531437          4.0  8.370208  12.370208
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          6.0  43.313167  49.313167          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Paperback_writer.wav 46 (31, 210) 48000
#   session run category     sr groupe                          title score  \
# 0       3   4   Lyrics  48000      U  Paperback_writer_silenced.wav     3
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration  S2_start  \
# 0          3  0.001354          4.0  ...  41.067646          4.0    10.826
#
#    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0   14.826          4.0  21.252896  25.252896          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Idaten_(level_5_1).wav 61 (41, 210) 48000
#   session run   category     sr groupe  \
# 0       3   4  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Shinobi_3_Return_Of_The_Ninja_Master_OST_Idate...     0          3
#
#       index  S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  \
# 0  0.000292          5.0  ...  53.813333          6.0  6.622562  12.622563
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  29.849708  33.849708          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Its_Raining_Men.wav 62 (42, 210) 48000
#   session run category     sr groupe                         title score  \
# 0       3   4   Lyrics  48000      F  Its_Raining_Men_silenced.wav     3
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          3  0.001604          4.0  ...  13.482396          4.0  35.449292
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  39.449292          4.0  47.749063  51.749063          4.0  23.659688
#
#      S4_stop
# 0  27.659688
#
# [1 rows x 21 columns]
# Another_Brick_In_The_Wall_(Part_1)_orchestral.wav 45 (30, 210) 48000
#   session run    category     sr groupe  \
# 0       3   4  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  Another_Brick_In_The_Wall_(Part_1)_orchestral_...     0          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001083          5.0  ...  34.799813          6.0  16.177833  22.177833
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Stairway_To_Heaven.wav 52 (35, 210) 48000
#   session run    category     sr groupe                            title  \
# 0       3   4  Orchestral  48000      F  Stairway_To_Heaven_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     3          3  0.001125          4.0  ...  15.612958          5.0
#
#     S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  25.831208  30.831208          4.0  41.689937  45.689937          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Overworld_1_Theme.wav 54 (36, 210) 48000
#   session run   category     sr groupe  \
# 0       3   4  Synthetic  48000      F
#
#                                                title score repetition  \
# 0  Super_Mario_Bros_3_Overworld_1_Theme_silenced.wav     4          3
#
#       index  S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000583          5.0  ...  13.14475          5.0  35.123104  40.123104
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  23.393687  27.393687          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Make_Em_Laugh.wav 65 (44, 210) 48000
#   session  run category     sr groupe                       title score  \
# 0       3    4   Lyrics  48000      U  Make_Em_Laugh_silenced.wav     3
# 1     NaN  NaN      NaN    NaN    NaN                         NaN   NaN
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          3  0.001000          5.0  ...  35.293875          6.0  16.790354
# 1        NaN  0.001625          4.0  ...  13.898771          4.0  52.103646
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  22.790354          4.0  52.674896  56.674896          NaN        NaN
# 1  56.103646          4.0  24.719146  28.719146          4.0  34.446062
#
#      S4_stop
# 0        NaN
# 1  38.446062
#
# [2 rows x 21 columns]
# Super_Mario_Bros_3_Airship.wav 60 (40, 210) 48000
#   session run   category     sr groupe  \
# 0       3   4  Synthetic  48000      F
#
#                                      title score repetition     index  \
# 0  Super_Mario_Bros_3_Airship_silenced.wav     4          3  0.000458
#
#    S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  S3_duration  \
# 0          4.0  ...  9.072083          5.0  46.630146  51.630146          6.0
#
#     S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  32.882104  38.882104          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Lux_Aeterna_from_Requiem_for_a_Dream.wav 60 (40, 210) 48000
#   session run    category     sr groupe  \
# 0       1   3  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  Lux_Aeterna_from_Requiem_for_a_Dream_silenced.wav     0          1
#
#       index  S1_duration  ...  S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000771          6.0  ...   13.926          4.0  29.763063  33.763062
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  40.842771  45.842771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Another_Brick_In_The_Wall_(Part_1)_lyrics.wav 60 (40, 210) 48000
#   session run category     sr groupe  \
# 0       1   3   Lyrics  48000      U
#
#                                                title score repetition  \
# 0  Another_Brick_In_The_Wall_(Part_1)_lyrics_sile...     1          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001708          4.0  ...  13.269979          6.0  44.086583  50.086583
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  20.907062  25.907062          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Seinfeld_Official_Soundtrack_(Seinfeld_Theme).wav 52 (35, 210) 48000
#   session run    category     sr groupe  \
# 0       1   3  Orchestral  48000      F
#
#                                                title score repetition  \
# 0  Seinfeld_Official_Soundtrack_(Seinfeld_Theme)_...     4          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000979          5.0  ...  24.054854          4.0  40.662542  44.662542
#
#    S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  8.522271  12.522271          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Material_Girl.wav 50 (34, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       1   3   Lyrics  48000      F  Material_Girl_silenced.wav     4
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001729          4.0  ...  41.991167          4.0  18.624063
#
#      S2_stop  S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  22.624063          4.0  7.444479  11.444479          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# The_4_Seasons_Op_8_4_RV_297_Winter.wav 60 (40, 210) 48000
#   session run    category     sr groupe  \
# 0       1   3  Orchestral  48000      F
#
#                                              title score repetition    index  \
# 0  The_4_Seasons_Op_8_4_RV_297_Winter_silenced.wav     3          1  0.00075
#
#    S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  S3_duration  \
# 0          5.0  ...  54.770792          6.0  6.897687  12.897687          4.0
#
#     S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  18.971875  22.971875          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Populous_(SNES_SFC)_BGM_01_Title_Theme.wav 49 (33, 210) 48000
#   session run   category     sr groupe  \
# 0       1   3  Synthetic  48000      U
#
#                                                title score repetition   index  \
# 0  Populous_(SNES_SFC)_BGM_01_Title_Theme_silence...     0          1  0.0005
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  37.720542          6.0  18.864021  24.864021
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# The_Pink_Panther_Theme.wav 45 (30, 210) 48000
#   session run    category     sr groupe                                title  \
# 0       1   3  Orchestral  48000      F  The_Pink_Panther_Theme_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          1  0.000937          5.0  ...  28.504229          6.0
#
#     S2_start    S2_stop  S3_duration  S3_start  S3_stop  S4_duration  \
# 0  38.234083  44.234083          NaN       NaN      NaN          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Goodbye_Blue_Sky.wav 48 (32, 210) 48000
#   session run category     sr groupe                          title score  \
# 0       1   3   Lyrics  48000      U  Goodbye_Blue_Sky_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration  S2_start  \
# 0          1  0.001521          6.0  ...  26.245562          6.0  5.299479
#
#      S2_stop  S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0  11.299479          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno.wav 53 (36, 210) 48000
#   session run    category     sr groupe  \
# 0       1   3  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno_silenc...     0          1
#
#       index  S1_duration  ...  S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000833          4.0  ...  25.3685          4.0  43.136458  47.136458
#
#    S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  7.484708  12.484708          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Monday_Monday.wav 53 (36, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       1   3   Lyrics  48000      F  Monday_Monday_silenced.wav     2
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001417          4.0  ...  14.102521          4.0  44.471583
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  48.471583          5.0  22.496021  27.496021          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# Streets_Of_Rage_1_OST_Stage_1.wav 45 (30, 210) 48000
#   session run   category     sr groupe  \
# 0       2   2  Synthetic  48000      U
#
#                                         title score repetition    index  \
# 0  Streets_Of_Rage_1_OST_Stage_1_silenced.wav     0          2  0.00025
#
#    S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  S3_duration  \
# 0          5.0  ...  30.75425          6.0  11.895896  17.895896          NaN
#
#    S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Moonlight_Sonata.wav 47 (32, 210) 48000
#   session run    category     sr groupe                          title score  \
# 0       2   2  Orchestral  48000      F  Moonlight_Sonata_silenced.wav     2
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001021          6.0  ...  40.494229          6.0  13.050833
#
#      S2_stop  S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0  19.050833          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Legend_of_Zelda_The_(NES)_Music_Overworld_Theme.wav 50 (34, 210) 48000
#   session run   category     sr groupe  \
# 0       2   2  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Legend_of_Zelda_The_(NES)_Music_Overworld_Them...     0          2
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000104          4.0  ...  41.970917          4.0  14.364688  18.364687
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  24.513021  28.513021          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_(NES)_Music_Overworld_Theme.wav 59 (40, 210) 48000
#   session run   category     sr groupe  \
# 0       2   2  Synthetic  48000      F
#
#                                                title score repetition  index  \
# 0  Super_Mario_Bros_(NES)_Music_Overworld_Theme_s...     4          2    0.0
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          5.0  ...  17.709646          4.0  34.984729  38.984729
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          6.0  48.033271  54.033271          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Gangstas_Paradise.wav 61 (41, 210) 48000
#   session run category     sr groupe                           title score  \
# 0       2   2   Lyrics  48000      F  Gangstas_Paradise_silenced.wav     2
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001667          5.0  ...  58.567875          5.0  41.285729
#
#      S2_stop  S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  46.285729          5.0  9.717625  14.717625          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# il_porco_rosso.wav 66 (44, 210) 48000
#   session run    category     sr groupe                        title score  \
# 0       2   2  Orchestral  48000      U  il_porco_rosso_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.000875          4.0  ...  43.998625          4.0  15.888458
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  19.888458          4.0  30.774062  34.774062          4.0  50.554917
#
#      S4_stop
# 0  54.554917
#
# [1 rows x 21 columns]
# Aladdin_Genesis_Music_Ending.wav 65 (44, 210) 48000
#   session run   category     sr groupe  \
# 0       2   2  Synthetic  48000      U
#
#                                        title score repetition     index  \
# 0  Aladdin_Genesis_Music_Ending_silenced.wav     4          2  0.000375
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  12.172729          5.0  21.721125  26.721125
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  46.125708  51.125708          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_(NES)_Music_Castle_Theme.wav 47 (32, 210) 48000
#   session run   category     sr groupe  \
# 0       2   2  Synthetic  48000      F
#
#                                                title score repetition  \
# 0  Super_Mario_Bros_(NES)_Music_Castle_Theme_sile...     2          2
#
#       index  S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000063          6.0  ...  24.55375          6.0  32.374187  38.374187
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# No_Woman_No_Cry.wav 64 (43, 210) 48000
#   session run category     sr groupe                         title score  \
# 0       2   2   Lyrics  48000      F  No_Woman_No_Cry_silenced.wav     3
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001271          5.0  ...  63.422729          5.0  32.528854
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  37.528854          6.0  43.767917  49.767917          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# Make_Em_Laugh.wav 60 (40, 210) 48000
#   session  run    category     sr groupe                       title score  \
# 0       2    2  Orchestral  48000      U  Make_Em_Laugh_silenced.wav     1
# 1     NaN  NaN         NaN    NaN    NaN                         NaN   NaN
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          2  0.001000          5.0  ...  35.293875          6.0  16.790354
# 1        NaN  0.001625          4.0  ...  13.898771          4.0  52.103646
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  22.790354          4.0  52.674896  56.674896          NaN        NaN
# 1  56.103646          4.0  24.719146  28.719146          4.0  34.446062
#
#      S4_stop
# 0        NaN
# 1  38.446062
#
# [2 rows x 21 columns]
# Lux_Aeterna_from_Requiem_for_a_Dream.wav 60 (40, 210) 48000
#   session run    category     sr groupe  \
# 0       3   3  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  Lux_Aeterna_from_Requiem_for_a_Dream_silenced.wav     3          3
#
#       index  S1_duration  ...  S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000771          6.0  ...   13.926          4.0  29.763063  33.763062
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  40.842771  45.842771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Another_Brick_In_The_Wall_(Part_1)_lyrics.wav 60 (40, 210) 48000
#   session run category     sr groupe  \
# ...
#
# [1 rows x 21 columns]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Idaten_(level_5_1).wav 61 (41, 210) 48000
#   session run   category     sr groupe  \
# 0       1   4  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Shinobi_3_Return_Of_The_Ninja_Master_OST_Idate...     1          1
#
#       index  S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  \
# 0  0.000292          5.0  ...  53.813333          6.0  6.622562  12.622563
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  29.849708  33.849708          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Its_Raining_Men.wav 62 (42, 210) 48000
#   session run category     sr groupe                         title score  \
# 0       1   4   Lyrics  48000      F  Its_Raining_Men_silenced.wav     4
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001604          4.0  ...  13.482396          4.0  35.449292
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  39.449292          4.0  47.749063  51.749063          4.0  23.659688
#
#      S4_stop
# 0  27.659688
#
# [1 rows x 21 columns]
# Another_Brick_In_The_Wall_(Part_1)_orchestral.wav 45 (30, 210) 48000
#   session run    category     sr groupe  \
# 0       1   4  Orchestral  48000      U
#
#                                                title score repetition  \
# 0  Another_Brick_In_The_Wall_(Part_1)_orchestral_...     0          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001083          5.0  ...  34.799813          6.0  16.177833  22.177833
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Stairway_To_Heaven.wav 52 (35, 210) 48000
#   session run    category     sr groupe                            title  \
# 0       1   4  Orchestral  48000      F  Stairway_To_Heaven_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          1  0.001125          4.0  ...  15.612958          5.0
#
#     S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  25.831208  30.831208          4.0  41.689937  45.689937          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Overworld_1_Theme.wav 54 (36, 210) 48000
#   session run   category     sr groupe  \
# 0       1   4  Synthetic  48000      F
#
#                                                title score repetition  \
# 0  Super_Mario_Bros_3_Overworld_1_Theme_silenced.wav     4          1
#
#       index  S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000583          5.0  ...  13.14475          5.0  35.123104  40.123104
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  23.393687  27.393687          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Make_Em_Laugh.wav 65 (44, 210) 48000
#   session  run category     sr groupe                       title score  \
# 0       1    4   Lyrics  48000      U  Make_Em_Laugh_silenced.wav     2
# 1     NaN  NaN      NaN    NaN    NaN                         NaN   NaN
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001000          5.0  ...  35.293875          6.0  16.790354
# 1        NaN  0.001625          4.0  ...  13.898771          4.0  52.103646
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration   S4_start  \
# 0  22.790354          4.0  52.674896  56.674896          NaN        NaN
# 1  56.103646          4.0  24.719146  28.719146          4.0  34.446062
#
#      S4_stop
# 0        NaN
# 1  38.446062
#
# [2 rows x 21 columns]
# Super_Mario_Bros_3_Airship.wav 60 (40, 210) 48000
#   session run   category     sr groupe  \
# 0       1   4  Synthetic  48000      F
#
#                                      title score repetition     index  \
# 0  Super_Mario_Bros_3_Airship_silenced.wav     3          1  0.000458
#
#    S1_duration  ...   S1_stop  S2_duration   S2_start    S2_stop  S3_duration  \
# 0          4.0  ...  9.072083          5.0  46.630146  51.630146          6.0
#
#     S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0  32.882104  38.882104          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# My_Name_is_Nobody_Good_Luck_Jack.wav 53 (36, 210) 48000
#   session run    category     sr groupe  \
# 0       1   6  Orchestral  48000      U
#
#                                            title score repetition     index  \
# 0  My_Name_is_Nobody_Good_Luck_Jack_silenced.wav     0          1  0.000812
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          5.0  ...  24.513646          4.0  36.858458  40.858458
#
#    S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  9.917125  13.917125          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Japonesque_(level_1_1).wav 44 (30, 210) 48000
#   session run   category     sr groupe  \
# 0       1   6  Synthetic  48000      F
#
#                                                title score repetition  \
# 0  Shinobi_3_Return_Of_The_Ninja_Master_OST_Japon...     4          1
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000479          6.0  ...  37.491771          5.0  14.778646  19.778646
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Everybody_Wants_To_Rule_The_World.wav 58 (39, 210) 48000
#   session run category     sr groupe  \
# 0       1   6   Lyrics  48000      F
#
#                                             title score repetition     index  \
# 0  Everybody_Wants_To_Rule_The_World_silenced.wav     2          1  0.001313
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          4.0  ...  19.393667          4.0  29.873958  33.873958
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          6.0  51.362354  57.362354          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# The_Moldau.wav 54 (36, 210) 48000
#   session run    category     sr groupe                    title score  \
# 0       1   6  Orchestral  48000      U  The_Moldau_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          1  0.001104          4.0  ...  24.200271          5.0  46.083917
#
#      S2_stop  S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0  51.083917          5.0   33.6445  38.6445          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Why_You_Wanna_Trip_on_Me.wav 53 (36, 210) 48000
#   session run category     sr groupe                                  title  \
# 0       1   6   Lyrics  48000      U  Why_You_Wanna_Trip_on_Me_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     0          1  0.001583          4.0  ...  13.622625          5.0
#
#     S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  44.914687  49.914687          4.0  33.210958  37.210958          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# 2001_l_odyssée_de_l_espace.wav 61 (41, 210) 48000
#   session run    category     sr groupe  \
# 0       1   6  Orchestral  48000      F
#
#                                      title score repetition     index  \
# 0  2001_l_odyssée_de_l_espace_silenced.wav     2          1  0.000646
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  45.425125          5.0  11.565125  16.565125
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  52.938187  56.938187          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Castle_Theme.wav 53 (36, 210) 48000
#   session run   category     sr groupe  \
# 0       1   6  Synthetic  48000      F
#
#                                           title score repetition     index  \
# 0  Super_Mario_Bros_3_Castle_Theme_silenced.wav     4          1  0.000083
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          5.0  ...  50.875854          4.0  32.725625  36.725625
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  14.114208  18.114208          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Kikis_Delivery_Service.wav 48 (32, 210) 48000
#   session run    category     sr groupe                                title  \
# 0       1   6  Orchestral  48000      U  Kikis_Delivery_Service_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     0          1  0.000667          6.0  ...  13.374937          6.0
#
#     S2_start    S2_stop  S3_duration  S3_start  S3_stop  S4_duration  \
# 0  23.497542  29.497542          NaN       NaN      NaN          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Murder_by_Numbers.wav 60 (40, 210) 48000
#   session run category     sr groupe                           title score  \
# 0       1   6   Lyrics  48000      U  Murder_by_Numbers_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration  S2_start  \
# 0          1  0.001563          4.0  ...  27.576563          5.0  7.434521
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  12.434521          6.0  47.415958  53.415958          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# I_Can't_Get_No_Satisfaction.wav 67 (45, 210) 48000
#   session run category     sr groupe  \
# 0       1   6   Lyrics  48000      F
#
#                                       title score repetition     index  \
# 0  I_Can't_Get_No_Satisfaction_silenced.wav     3          1  0.001479
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  32.037354          5.0  51.864458  56.864458
#
#    S3_duration  S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          6.0  9.191437  15.191437          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme.wav 54 (36, 210) 48000
#   session run   category     sr groupe  \
# 0       3   5  Synthetic  48000      U
#
#                                                title score repetition  \
# 0  Super_Mario_64_BobOmb_Battlefield_(Extended)_T...     0          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000542          4.0  ...  53.435563          5.0  38.836958  43.836958
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          5.0  20.406021  25.406021          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Underwater_Theme.wav 46 (31, 210) 48000
#   session run   category     sr groupe  \
# 0       3   5  Synthetic  48000      F
#
#                                               title score repetition  \
# 0  Super_Mario_Bros_3_Underwater_Theme_silenced.wav     4          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000208          4.0  ...  42.086417          4.0  12.343229  16.343229
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  26.447813  30.447813          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Space_Harrier_Music_MAIN_THEME.wav 48 (32, 210) 48000
#   session run   category     sr groupe  \
# 0       3   5  Synthetic  48000      U
#
#                                          title score repetition     index  \
# 0  Space_Harrier_Music_MAIN_THEME_silenced.wav     0          3  0.000604
#
#    S1_duration  ...    S1_stop  S2_duration  S2_start    S2_stop  S3_duration  \
# 0          6.0  ...  33.167458          6.0  5.150083  11.150083          NaN
#
#    S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Dreaming_of_Bag_End.wav 52 (35, 210) 48000
#   session run    category     sr groupe                             title  \
# 0       3   5  Orchestral  48000      U  Dreaming_of_Bag_End_silenced.wav
#
#   score repetition     index  S1_duration  ...    S1_stop  S2_duration  \
# 0     0          3  0.000917          4.0  ...  42.534917          4.0
#
#    S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  7.577625  11.577625          5.0  26.528479  31.528479          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
# Creep.wav 49 (33, 210) 48000
#   session run category     sr groupe               title score repetition  \
# 0       3   5   Lyrics  48000      F  Creep_silenced.wav     2          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.001646          4.0  ...  11.254437          4.0  28.208938  32.208937
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  42.302771  46.302771          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Super_Mario_Bros_3_Athletic_Theme.wav 50 (34, 210) 48000
#   session run   category     sr groupe  \
# 0       3   5  Synthetic  48000      F
#
#                                             title score repetition     index  \
# 0  Super_Mario_Bros_3_Athletic_Theme_silenced.wav     4          3  0.000125
#
#    S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0          6.0  ...  16.971146          6.0  38.193375  44.193375
#
#    S3_duration  S3_start  S3_stop  S4_duration  S4_start  S4_stop
# 0          NaN       NaN      NaN          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Star_Trek_the_Next_Generation_(Main_Title).wav 56 (38, 210) 48000
#   session run    category     sr groupe  \
# 0       3   5  Orchestral  48000      F
#
#                                                title score repetition  \
# 0  Star_Trek_the_Next_Generation_(Main_Title)_sil...     3          3
#
#       index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.000729          5.0  ...  12.566896          5.0  40.667979  45.667979
#
#    S3_duration  S3_start   S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  18.95725  22.95725          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Rain.wav 48 (32, 210) 48000
#   session run category     sr groupe              title score repetition  \
# 0       3   5   Lyrics  48000      U  Rain_silenced.wav     0          3
#
#     index  S1_duration  ...    S1_stop  S2_duration   S2_start    S2_stop  \
# 0  0.0015          4.0  ...  47.641125          4.0  30.042458  34.042458
#
#    S3_duration   S3_start    S3_stop  S4_duration  S4_start  S4_stop
# 0          4.0  19.668792  23.668792          NaN       NaN      NaN
#
# [1 rows x 21 columns]
# Synchronicity.wav 47 (32, 210) 48000
#   session run category     sr groupe                       title score  \
# 0       3   5   Lyrics  48000      U  Synchronicity_silenced.wav     0
#
#   repetition     index  S1_duration  ...    S1_stop  S2_duration   S2_start  \
# 0          3  0.001396          4.0  ...  13.070875          4.0  19.838062
#
#      S2_stop  S3_duration   S3_start    S3_stop  S4_duration  S4_start  \
# 0  23.838062          4.0  35.685208  39.685208          NaN       NaN
#
#    S4_stop
# 0      NaN
#
# [1 rows x 21 columns]
# I_ll_Be_There_for_You.wav 47 (32, 210) 48000
#   session run category     sr groupe                               title  \
# 0       3   5   Lyrics  48000      F  I_ll_Be_There_for_You_silenced.wav
#
#   score repetition    index  S1_duration  ...    S1_stop  S2_duration  \
# 0     4          3  0.00175          4.0  ...  39.415062          4.0
#
#     S2_start    S2_stop  S3_duration   S3_start    S3_stop  S4_duration  \
# 0  14.130021  18.130021          4.0  24.439187  28.439187          NaN
#
#    S4_start  S4_stop
# 0       NaN      NaN
#
# [1 rows x 21 columns]
