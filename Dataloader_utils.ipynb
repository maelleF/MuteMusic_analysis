# %%
import os, pickle
import numpy as np
import pandas as pd
import librosa

# %%
#paths
tracks_path = '/home/maellef/git/MuteMusic_stimuli/data/StimuliFinal/silenced1_normalized'
data_path = '/home/maellef/DataBase/MuteMusic/Preprocessed_fMRI'
scale = 'MISTROI'
sub = 'sub-03'
filename = 'sub-03_ses-001_task-mutemusic_run-1.npz'

sessions_data = 'sub_session_data.tsv'
sessions_df = pd.read_csv(sessions_data, sep='\t')
silences_data = 'silences_data.tsv'
silences_df = pd.read_csv(silences_data, sep='\t')

path = os.path.join(data_path, scale, sub, filename)
with np.load(path) as data:
    x = data['X']
data.close()

# %%
def find_label_value(name, label):
    label += '-' if label[-1] != '-' else label
    startval = name.find(label)+len(label)
    endval = startval
    for i in range(startval, len(name)):
        if name[i] in ['_', '.']:
            break
        endval+=1
    return int(name[startval:endval])

# %%
#structure to store all data pair (wav-fMRI)
df = pd.DataFrame({
    'stimuli':[],
    'groupe':[],
    'category':[],
    'score':[],
})
wavbold = []
#general args
tr = 1.49
hrf_nb_tr = 2
sr=22050

sub_path = os.path.join(data_path, scale, sub)

for filename in os.listdir(sub_path):
    print(filename)
    #load bold data
    runpath = os.path.join(sub_path, filename)
    with np.load(runpath) as data:
        x = data['X']
    data.close()
    
    #args necessary to extract infos from run
    sub = sub
    ses = find_label_value(filename, 'ses')
    run = find_label_value(filename, 'run')
    
    run_data = sessions_df.loc[(sessions_df['sub']==sub)&
                                (sessions_df['session']==ses)&
                                (sessions_df['run']==run)]
    
    #extract data from each track in a run
    for i, track in run_data.iterrows():
        #track infos
        groupe = track['Groupe']
        category = track['category']
        score = track['value']
        title_silenced = track['title']
        title = title_silenced.replace('_silenced','')
        onset = round(track['onset'])
        duration = round(track['total_duration'])
    
        #load silenced track
        wav_path = os.path.join(tracks_path, category, title_silenced)
        wav, sr = librosa.load(wav_path, sr=sr)
        print(sr)
        
        #bold data for track (WITH HRF delay !!!!!)
        tr_onset = round(onset/tr) + hrf_nb_tr
        tr_duration = round(duration/tr)
        track_fmri = x[tr_onset:tr_onset+tr_duration, :]
    
        #define timestamps to extract both music and silence    
        sdf = silences_df.loc[silences_df['track']==title]
        print(title)
        timestamps_s = {'duration':[sdf['S1_duration'].values[0], sdf['S2_duration'].values[0], sdf['S3_duration'].values[0], sdf['S4_duration'].values[0]],
                        'start':[sdf['S1_start'].values[0], sdf['S2_start'].values[0], sdf['S3_start'].values[0], sdf['S4_start'].values[0]],
                        'stop':[sdf['S1_stop'].values[0], sdf['S2_stop'].values[0], sdf['S3_stop'].values[0], sdf['S4_stop'].values[0]]}
        siltt_df = pd.DataFrame(timestamps_s).sort_values(by='start').dropna()
        
        alltt = []
        music_start = 0
        for i, silence_tt in siltt_df.iterrows():
            silence_start = int(silence_tt['start'])
            music_stop = silence_start-1
            silence_stop = int(silence_tt['stop'])
            alltt+=[('m', music_start, music_stop), ('s', silence_start, silence_stop)]
            music_start = silence_stop+1
        alltt.append(('m', music_start, duration*sr))
    
        #extract corresponding wav/bold
        alltr = [(stim, round(start/sr/tr), round(stop/sr/tr)) for (stim, start, stop) in alltt]
        for (stim, tr_start, tr_stop) in alltr:
            bold_segment = track_fmri[tr_start:tr_stop]
            wav_segment = wav[int(tr_start*tr*sr):int(tr_stop*tr*sr)]
            segment_df = pd.Series({
                'stimuli':stim,
                'groupe':groupe,
                'category':category,
                'score':score}).to_frame().T
            df = pd.concat([df, segment_df], axis='rows', ignore_index=True)  
            wavbold.append((wav_segment, bold_segment))
df.to_csv(f'{sub}_metadata.tsv', sep='\t')
with open(f'{sub}_pairWavBold', 'wb') as f: 
    pickle.dump(wavbold, f)
# Out:
# sub-03_ses-001_task-mutemusic_run-5.npz
# 22050
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme.wav
# 22050
# Super_Mario_Bros_3_Underwater_Theme.wav
# 22050
# Space_Harrier_Music_MAIN_THEME.wav
# 22050
# Dreaming_of_Bag_End.wav
# 22050
# Creep.wav
# 22050
# Super_Mario_Bros_3_Athletic_Theme.wav
# 22050
# Star_Trek_the_Next_Generation_(Main_Title).wav
# 22050
# Rain.wav
# 22050
# Synchronicity.wav
# 22050
# I_ll_Be_There_for_You.wav
# sub-03_ses-002_task-mutemusic_run-5.npz
# 22050
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme.wav
# 22050
# Super_Mario_Bros_3_Underwater_Theme.wav
# 22050
# Space_Harrier_Music_MAIN_THEME.wav
# 22050
# Dreaming_of_Bag_End.wav
# 22050
# Creep.wav
# 22050
# Super_Mario_Bros_3_Athletic_Theme.wav
# 22050
# Star_Trek_the_Next_Generation_(Main_Title).wav
# 22050
# Rain.wav
# 22050
# Synchronicity.wav
# 22050
# I_ll_Be_There_for_You.wav
# sub-03_ses-003_task-mutemusic_run-1.npz
# 22050
# Sonic_The_Hedgehog_OST_Green_Hill_Zone.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Shinobi_Walk_(level_4_2).wav
# 22050
# Living_Together.wav
# 22050
# Body_and_soul.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Underground_Theme.wav
# 22050
# The_Imperial_March_(Darth_Vaders_Theme).wav
# 22050
# Main_Title_Terminator_2_Theme_(Remastered_2017).wav
# 22050
# Never_Gonna_Give_You_Up.wav
# 22050
# Super_Mario_Bros_3_Boss_Battle.wav
# 22050
# Original_Tetris_theme_(Tetris_Soundtrack).wav
# sub-03_ses-001_task-mutemusic_run-2.npz
# 22050
# Streets_Of_Rage_1_OST_Stage_1.wav
# 22050
# Moonlight_Sonata.wav
# 22050
# Legend_of_Zelda_The_(NES)_Music_Overworld_Theme.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Overworld_Theme.wav
# 22050
# Gangstas_Paradise.wav
# 22050
# il_porco_rosso.wav
# 22050
# Aladdin_Genesis_Music_Ending.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Castle_Theme.wav
# 22050
# No_Woman_No_Cry.wav
# 22050
# Make_Em_Laugh.wav
# sub-03_ses-002_task-mutemusic_run-3.npz
# 22050
# Lux_Aeterna_from_Requiem_for_a_Dream.wav
# 22050
# Another_Brick_In_The_Wall_(Part_1)_lyrics.wav
# 22050
# Seinfeld_Official_Soundtrack_(Seinfeld_Theme).wav
# 22050
# Material_Girl.wav
# 22050
# The_4_Seasons_Op_8_4_RV_297_Winter.wav
# 22050
# Populous_(SNES_SFC)_BGM_01_Title_Theme.wav
# 22050
# The_Pink_Panther_Theme.wav
# 22050
# Goodbye_Blue_Sky.wav
# 22050
# My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno.wav
# 22050
# Monday_Monday.wav
# sub-03_ses-003_task-mutemusic_run-4.npz
# 22050
# Gnossienne_No1.wav
# 22050
# Babooshka.wav
# 22050
# Paperback_writer.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Idaten_(level_5_1).wav
# 22050
# Its_Raining_Men.wav
# 22050
# Another_Brick_In_The_Wall_(Part_1)_orchestral.wav
# 22050
# Stairway_To_Heaven.wav
# 22050
# Super_Mario_Bros_3_Overworld_1_Theme.wav
# 22050
# Make_Em_Laugh.wav
# 22050
# Super_Mario_Bros_3_Airship.wav
# sub-03_ses-001_task-mutemusic_run-3.npz
# 22050
# Lux_Aeterna_from_Requiem_for_a_Dream.wav
# 22050
# Another_Brick_In_The_Wall_(Part_1)_lyrics.wav
# 22050
# Seinfeld_Official_Soundtrack_(Seinfeld_Theme).wav
# 22050
# Material_Girl.wav
# 22050
# The_4_Seasons_Op_8_4_RV_297_Winter.wav
# 22050
# Populous_(SNES_SFC)_BGM_01_Title_Theme.wav
# 22050
# The_Pink_Panther_Theme.wav
# 22050
# Goodbye_Blue_Sky.wav
# 22050
# My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno.wav
# 22050
# Monday_Monday.wav
# sub-03_ses-002_task-mutemusic_run-2.npz
# 22050
# Streets_Of_Rage_1_OST_Stage_1.wav
# 22050
# Moonlight_Sonata.wav
# 22050
# Legend_of_Zelda_The_(NES)_Music_Overworld_Theme.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Overworld_Theme.wav
# 22050
# Gangstas_Paradise.wav
# 22050
# il_porco_rosso.wav
# 22050
# Aladdin_Genesis_Music_Ending.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Castle_Theme.wav
# 22050
# No_Woman_No_Cry.wav
# 22050
# Make_Em_Laugh.wav
# sub-03_ses-003_task-mutemusic_run-3.npz
# 22050
# Lux_Aeterna_from_Requiem_for_a_Dream.wav
# 22050
# Another_Brick_In_The_Wall_(Part_1)_lyrics.wav
# 22050
# Seinfeld_Official_Soundtrack_(Seinfeld_Theme).wav
# 22050
# Material_Girl.wav
# 22050
# The_4_Seasons_Op_8_4_RV_297_Winter.wav
# 22050
# Populous_(SNES_SFC)_BGM_01_Title_Theme.wav
# 22050
# The_Pink_Panther_Theme.wav
# 22050
# Goodbye_Blue_Sky.wav
# 22050
# My_Name_is_Nobody_Il_Mio_Nome_e_Nessuno.wav
# 22050
# Monday_Monday.wav
# sub-03_ses-002_task-mutemusic_run-1.npz
# 22050
# Sonic_The_Hedgehog_OST_Green_Hill_Zone.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Shinobi_Walk_(level_4_2).wav
# 22050
# Living_Together.wav
# 22050
# Body_and_soul.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Underground_Theme.wav
# 22050
# The_Imperial_March_(Darth_Vaders_Theme).wav
# 22050
# Main_Title_Terminator_2_Theme_(Remastered_2017).wav
# 22050
# Never_Gonna_Give_You_Up.wav
# 22050
# Super_Mario_Bros_3_Boss_Battle.wav
# 22050
# Original_Tetris_theme_(Tetris_Soundtrack).wav
# sub-03_ses-003_task-mutemusic_run-2.npz
# 22050
# Streets_Of_Rage_1_OST_Stage_1.wav
# 22050
# Moonlight_Sonata.wav
# 22050
# Legend_of_Zelda_The_(NES)_Music_Overworld_Theme.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Overworld_Theme.wav
# 22050
# Gangstas_Paradise.wav
# 22050
# il_porco_rosso.wav
# 22050
# Aladdin_Genesis_Music_Ending.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Castle_Theme.wav
# 22050
# No_Woman_No_Cry.wav
# 22050
# Make_Em_Laugh.wav
# sub-03_ses-003_task-mutemusic_run-6.npz
# 22050
# My_Name_is_Nobody_Good_Luck_Jack.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Japonesque_(level_1_1).wav
# 22050
# Everybody_Wants_To_Rule_The_World.wav
# 22050
# The_Moldau.wav
# 22050
# Why_You_Wanna_Trip_on_Me.wav
# 22050
# 2001_l_odyssée_de_l_espace.wav
# 22050
# Super_Mario_Bros_3_Castle_Theme.wav
# 22050
# Kikis_Delivery_Service.wav
# 22050
# Murder_by_Numbers.wav
# 22050
# I_Can't_Get_No_Satisfaction.wav
# sub-03_ses-002_task-mutemusic_run-6.npz
# 22050
# My_Name_is_Nobody_Good_Luck_Jack.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Japonesque_(level_1_1).wav
# 22050
# Everybody_Wants_To_Rule_The_World.wav
# 22050
# The_Moldau.wav
# 22050
# Why_You_Wanna_Trip_on_Me.wav
# 22050
# 2001_l_odyssée_de_l_espace.wav
# 22050
# Super_Mario_Bros_3_Castle_Theme.wav
# 22050
# Kikis_Delivery_Service.wav
# 22050
# Murder_by_Numbers.wav
# 22050
# I_Can't_Get_No_Satisfaction.wav
# sub-03_ses-001_task-mutemusic_run-1.npz
# 22050
# Sonic_The_Hedgehog_OST_Green_Hill_Zone.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Shinobi_Walk_(level_4_2).wav
# 22050
# Living_Together.wav
# 22050
# Body_and_soul.wav
# 22050
# Super_Mario_Bros_(NES)_Music_Underground_Theme.wav
# 22050
# The_Imperial_March_(Darth_Vaders_Theme).wav
# 22050
# Main_Title_Terminator_2_Theme_(Remastered_2017).wav
# 22050
# Never_Gonna_Give_You_Up.wav
# 22050
# Super_Mario_Bros_3_Boss_Battle.wav
# 22050
# Original_Tetris_theme_(Tetris_Soundtrack).wav
# sub-03_ses-002_task-mutemusic_run-4.npz
# 22050
# Gnossienne_No1.wav
# 22050
# Babooshka.wav
# 22050
# Paperback_writer.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Idaten_(level_5_1).wav
# 22050
# Its_Raining_Men.wav
# 22050
# Another_Brick_In_The_Wall_(Part_1)_orchestral.wav
# 22050
# Stairway_To_Heaven.wav
# 22050
# Super_Mario_Bros_3_Overworld_1_Theme.wav
# 22050
# Make_Em_Laugh.wav
# 22050
# Super_Mario_Bros_3_Airship.wav
# sub-03_ses-001_task-mutemusic_run-4.npz
# 22050
# Gnossienne_No1.wav
# 22050
# Babooshka.wav
# 22050
# Paperback_writer.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Idaten_(level_5_1).wav
# 22050
# Its_Raining_Men.wav
# 22050
# Another_Brick_In_The_Wall_(Part_1)_orchestral.wav
# 22050
# Stairway_To_Heaven.wav
# 22050
# Super_Mario_Bros_3_Overworld_1_Theme.wav
# 22050
# Make_Em_Laugh.wav
# 22050
# Super_Mario_Bros_3_Airship.wav
# sub-03_ses-001_task-mutemusic_run-6.npz
# 22050
# My_Name_is_Nobody_Good_Luck_Jack.wav
# 22050
# Shinobi_3_Return_Of_The_Ninja_Master_OST_Japonesque_(level_1_1).wav
# 22050
# Everybody_Wants_To_Rule_The_World.wav
# 22050
# The_Moldau.wav
# 22050
# Why_You_Wanna_Trip_on_Me.wav
# 22050
# 2001_l_odyssée_de_l_espace.wav
# 22050
# Super_Mario_Bros_3_Castle_Theme.wav
# 22050
# Kikis_Delivery_Service.wav
# 22050
# Murder_by_Numbers.wav
# 22050
# I_Can't_Get_No_Satisfaction.wav
# sub-03_ses-003_task-mutemusic_run-5.npz
# 22050
# Super_Mario_64_BobOmb_Battlefield_(Extended)_Theme.wav
# 22050
# Super_Mario_Bros_3_Underwater_Theme.wav
# 22050
# Space_Harrier_Music_MAIN_THEME.wav
# 22050
# Dreaming_of_Bag_End.wav
# 22050
# Creep.wav
# 22050
# Super_Mario_Bros_3_Athletic_Theme.wav
# 22050
# Star_Trek_the_Next_Generation_(Main_Title).wav
# 22050
# Rain.wav
# 22050
# Synchronicity.wav
# 22050
# I_ll_Be_There_for_You.wav
